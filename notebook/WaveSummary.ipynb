# %%
# run without Qt
import os
os.environ['PYTPLOT_NO_GRAPHICS'] = '1'

import matplotlib
from matplotlib import pyplot as plt

import pytplot
import pyspedas
import insitu
from mmstools import wavepol

# %%
reload(wavepol)
probe  = 1
trange = ['2017-07-15 10:26:00', '2017-07-15 10:28:00']

fig, data = wavepol.load_and_plot(probe, trange, backend='plotly')
